# %%
import cantera as ct
import numpy as np
import csv

# %config InlineBackend.figure_formats = ["svg"]
# %matplotlib inline
import matplotlib.pylab as plt

print('running cantera version: ' + ct.__version__)
# Out:
# running cantera version: 3.0.0

# %%
gas = ct.Solution("data/chem.yaml")
# Out:
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species H2, discontinuity in cp/R detected at Tmid = 2.01
# 	Value computed using low-temperature polynomial:  2.3602934365979036
# 	Value computed using high-temperature polynomial: 2.9345266806587236
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species H2, discontinuity in h/RT detected at Tmid = 2.01
# 	Value computed using low-temperature polynomial:  -454.33184031861595
# 	Value computed using high-temperature polynomial: -401.57655092980355
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species H2, discontinuity in s/R detected at Tmid = 2.01
# 	Value computed using low-temperature polynomial:  2.335670747304918
# 	Value computed using high-temperature polynomial: 1.024867759488491
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species O2, discontinuity in h/RT detected at Tmid = 31.99
# 	Value computed using low-temperature polynomial:  -29.520825417914907
# 	Value computed using high-temperature polynomial: -34.33975613657743
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species O2, discontinuity in s/R detected at Tmid = 31.99
# 	Value computed using low-temperature polynomial:  16.674556680613097
# 	Value computed using high-temperature polynomial: 16.123066132160353
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species O, discontinuity in cp/R detected at Tmid = 15.99
# 	Value computed using low-temperature polynomial:  3.117504375590273
# 	Value computed using high-temperature polynomial: 2.543199132035348
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species O, discontinuity in h/RT detected at Tmid = 15.99
# 	Value computed using low-temperature polynomial:  1824.4221085638385
# 	Value computed using high-temperature polynomial: 1830.3115232901912
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species O, discontinuity in s/R detected at Tmid = 15.99
# 	Value computed using low-temperature polynomial:  10.782658929235218
# 	Value computed using high-temperature polynomial: 11.972726160618528
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species OH, discontinuity in cp/R detected at Tmid = 17
# 	Value computed using low-temperature polynomial:  3.9525086622846635
# 	Value computed using high-temperature polynomial: 2.8573846845926583
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species OH, discontinuity in h/RT detected at Tmid = 17
# 	Value computed using low-temperature polynomial:  216.6238419953234
# 	Value computed using high-temperature polynomial: 234.84558948261088
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species OH, discontinuity in s/R detected at Tmid = 17
# 	Value computed using low-temperature polynomial:  11.16614449469493
# 	Value computed using high-temperature polynomial: 13.905797492299701
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HO2, discontinuity in cp/R detected at Tmid = 33
# 	Value computed using low-temperature polynomial:  4.167257009269915
# 	Value computed using high-temperature polynomial: 4.233989707163639
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HO2, discontinuity in h/RT detected at Tmid = 33
# 	Value computed using low-temperature polynomial:  13.164479049048978
# 	Value computed using high-temperature polynomial: 6.076240452831667
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HO2, discontinuity in s/R detected at Tmid = 33
# 	Value computed using low-temperature polynomial:  18.612443379551756
# 	Value computed using high-temperature polynomial: 17.608001991824654
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species H2O2, discontinuity in cp/R detected at Tmid = 34.01
# 	Value computed using low-temperature polynomial:  4.276169411871034
# 	Value computed using high-temperature polynomial: 4.709580534471628
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species H2O2, discontinuity in h/RT detected at Tmid = 34.01
# 	Value computed using low-temperature polynomial:  -517.7585991277546
# 	Value computed using high-temperature polynomial: -526.2260420941108
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species H2O2, discontinuity in s/R detected at Tmid = 34.01
# 	Value computed using low-temperature polynomial:  18.50635947415301
# 	Value computed using high-temperature polynomial: 16.96984153713227
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species H2O, discontinuity in cp/R detected at Tmid = 18.01
# 	Value computed using low-temperature polynomial:  4.1640474673509615
# 	Value computed using high-temperature polynomial: 2.7303344722452962
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species H2O, discontinuity in h/RT detected at Tmid = 18.01
# 	Value computed using low-temperature polynomial:  -1677.869344773688
# 	Value computed using high-temperature polynomial: -1656.701813502562
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species H2O, discontinuity in s/R detected at Tmid = 18.01
# 	Value computed using low-temperature polynomial:  11.253302479772398
# 	Value computed using high-temperature polynomial: 14.675098919376222
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NO, discontinuity in cp/R detected at Tmid = 30
# 	Value computed using low-temperature polynomial:  4.089092474717589
# 	Value computed using high-temperature polynomial: 3.2960583419518548
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NO, discontinuity in h/RT detected at Tmid = 30
# 	Value computed using low-temperature polynomial:  332.32223943862215
# 	Value computed using high-temperature polynomial: 333.9928265749112
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NO, discontinuity in s/R detected at Tmid = 30
# 	Value computed using low-temperature polynomial:  16.494587750167682
# 	Value computed using high-temperature polynomial: 17.494869312687428
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HNO, discontinuity in cp/R detected at Tmid = 31.01
# 	Value computed using low-temperature polynomial:  4.376254210661443
# 	Value computed using high-temperature polynomial: 3.2581988524113092
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HNO, discontinuity in h/RT detected at Tmid = 31.01
# 	Value computed using low-temperature polynomial:  360.4632502873218
# 	Value computed using high-temperature polynomial: 364.20570970082986
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HNO, discontinuity in s/R detected at Tmid = 31.01
# 	Value computed using low-temperature polynomial:  17.151059485404996
# 	Value computed using high-temperature polynomial: 18.61195955401731
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NO2, discontinuity in cp/R detected at Tmid = 46
# 	Value computed using low-temperature polynomial:  3.904397441601288
# 	Value computed using high-temperature polynomial: 4.982938509880686
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NO2, discontinuity in h/RT detected at Tmid = 46
# 	Value computed using low-temperature polynomial:  66.88836716510603
# 	Value computed using high-temperature polynomial: 55.292490922222285
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NO2, discontinuity in s/R detected at Tmid = 46
# 	Value computed using low-temperature polynomial:  21.35631017256402
# 	Value computed using high-temperature polynomial: 18.68363726893214
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NO3, discontinuity in cp/R detected at Tmid = 62
# 	Value computed using low-temperature polynomial:  2.8599469217515505
# 	Value computed using high-temperature polynomial: 7.6394565566101384
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NO3, discontinuity in h/RT detected at Tmid = 62
# 	Value computed using low-temperature polynomial:  121.7403218713121
# 	Value computed using high-temperature polynomial: 99.64588216495636
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NO3, discontinuity in s/R detected at Tmid = 62
# 	Value computed using low-temperature polynomial:  24.24236383964681
# 	Value computed using high-temperature polynomial: 16.881393285673752
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HNO3, discontinuity in cp/R detected at Tmid = 63.01
# 	Value computed using low-temperature polynomial:  2.896001746879859
# 	Value computed using high-temperature polynomial: 8.28041384629274
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HNO3, discontinuity in h/RT detected at Tmid = 63.01
# 	Value computed using low-temperature polynomial:  -273.5114326835195
# 	Value computed using high-temperature polynomial: -297.4638475529988
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HNO3, discontinuity in s/R detected at Tmid = 63.01
# 	Value computed using low-temperature polynomial:  25.352489902160983
# 	Value computed using high-temperature polynomial: 17.34352562349725
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N2O, discontinuity in cp/R detected at Tmid = 44.01
# 	Value computed using low-temperature polynomial:  2.7290206655445624
# 	Value computed using high-temperature polynomial: 4.936953766253963
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N2O, discontinuity in h/RT detected at Tmid = 44.01
# 	Value computed using low-temperature polynomial:  201.1287853757643
# 	Value computed using high-temperature polynomial: 188.32406322281457
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N2O, discontinuity in s/R detected at Tmid = 44.01
# 	Value computed using low-temperature polynomial:  19.78453205380361
# 	Value computed using high-temperature polynomial: 16.16527499914631
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N, discontinuity in cp/R detected at Tmid = 14
# 	Value computed using low-temperature polynomial:  2.5
# 	Value computed using high-temperature polynomial: 2.4183681526238483
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N, discontinuity in h/RT detected at Tmid = 14
# 	Value computed using low-temperature polynomial:  4009.974128571428
# 	Value computed using high-temperature polynomial: 4011.972502265849
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N, discontinuity in s/R detected at Tmid = 14
# 	Value computed using low-temperature polynomial:  10.791552644038147
# 	Value computed using high-temperature polynomial: 11.027858589056674
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N2, discontinuity in cp/R detected at Tmid = 28.01
# 	Value computed using low-temperature polynomial:  3.5271995524316657
# 	Value computed using high-temperature polynomial: 2.991318670260152
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N2, discontinuity in h/RT detected at Tmid = 28.01
# 	Value computed using low-temperature polynomial:  -33.84950540910287
# 	Value computed using high-temperature polynomial: -30.014373590372557
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N2, discontinuity in s/R detected at Tmid = 28.01
# 	Value computed using low-temperature polynomial:  14.731123809007618
# 	Value computed using high-temperature polynomial: 15.750469263911164
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NH, discontinuity in cp/R detected at Tmid = 15.01
# 	Value computed using low-temperature polynomial:  3.4973032768450136
# 	Value computed using high-temperature polynomial: 2.803592191937497
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NH, discontinuity in h/RT detected at Tmid = 15.01
# 	Value computed using low-temperature polynomial:  2794.587385852091
# 	Value computed using high-temperature polynomial: 2809.890030968343
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NH, discontinuity in s/R detected at Tmid = 15.01
# 	Value computed using low-temperature polynomial:  11.314277644356071
# 	Value computed using high-temperature polynomial: 13.301088159661433
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NH2, discontinuity in cp/R detected at Tmid = 16.02
# 	Value computed using low-temperature polynomial:  4.173197169392958
# 	Value computed using high-temperature polynomial: 2.897807489198446
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NH2, discontinuity in h/RT detected at Tmid = 16.02
# 	Value computed using low-temperature polynomial:  1348.4601828997306
# 	Value computed using high-temperature polynomial: 1365.1639792684261
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NH2, discontinuity in s/R detected at Tmid = 16.02
# 	Value computed using low-temperature polynomial:  11.485614964294973
# 	Value computed using high-temperature polynomial: 14.420917202350426
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NH3, discontinuity in cp/R detected at Tmid = 17.03
# 	Value computed using low-temperature polynomial:  4.226771830953539
# 	Value computed using high-temperature polynomial: 2.8114178663478895
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NH3, discontinuity in h/RT detected at Tmid = 17.03
# 	Value computed using low-temperature polynomial:  -391.9824376631303
# 	Value computed using high-temperature polynomial: -383.87804674836195
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NH3, discontinuity in s/R detected at Tmid = 17.03
# 	Value computed using low-temperature polynomial:  11.42668357934718
# 	Value computed using high-temperature polynomial: 13.890380842497086
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N2H2, discontinuity in cp/R detected at Tmid = 30.02
# 	Value computed using low-temperature polynomial:  4.620867164672767
# 	Value computed using high-temperature polynomial: 1.578562095133084
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N2H2, discontinuity in h/RT detected at Tmid = 30.02
# 	Value computed using low-temperature polynomial:  811.6980144424637
# 	Value computed using high-temperature polynomial: 827.1087739272671
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N2H2, discontinuity in s/R detected at Tmid = 30.02
# 	Value computed using low-temperature polynomial:  16.489904578633684
# 	Value computed using high-temperature polynomial: 21.13828674308682
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N2H4, discontinuity in cp/R detected at Tmid = 32.04
# 	Value computed using low-temperature polynomial:  3.8509837417935104
# 	Value computed using high-temperature polynomial: 5.216870901448034
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N2H4, discontinuity in h/RT detected at Tmid = 32.04
# 	Value computed using low-temperature polynomial:  318.73670103322644
# 	Value computed using high-temperature polynomial: 294.7995633637798
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species N2H4, discontinuity in s/R detected at Tmid = 32.04
# 	Value computed using low-temperature polynomial:  19.045643847026646
# 	Value computed using high-temperature polynomial: 14.709854221933698
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species CL, discontinuity in cp/R detected at Tmid = 35.45
# 	Value computed using low-temperature polynomial:  2.314348174967176
# 	Value computed using high-temperature polynomial: 2.9330705191450934
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species CL, discontinuity in h/RT detected at Tmid = 35.45
# 	Value computed using low-temperature polynomial:  393.12822734351136
# 	Value computed using high-temperature polynomial: 389.3158975068384
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species CL, discontinuity in s/R detected at Tmid = 35.45
# 	Value computed using low-temperature polynomial:  14.690592882172336
# 	Value computed using high-temperature polynomial: 13.613476787496289
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species CL2, discontinuity in cp/R detected at Tmid = 70.9
# 	Value computed using low-temperature polynomial:  3.223335988068876
# 	Value computed using high-temperature polynomial: 4.713975354415703
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species CL2, discontinuity in h/RT detected at Tmid = 70.9
# 	Value computed using low-temperature polynomial:  -11.942798984430285
# 	Value computed using high-temperature polynomial: -16.581566761583947
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species CL2, discontinuity in s/R detected at Tmid = 70.9
# 	Value computed using low-temperature polynomial:  21.626535384234572
# 	Value computed using high-temperature polynomial: 19.85090300166566
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HCL, discontinuity in cp/R detected at Tmid = 36.46
# 	Value computed using low-temperature polynomial:  3.524864113130429
# 	Value computed using high-temperature polynomial: 2.8184036072188126
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HCL, discontinuity in h/RT detected at Tmid = 36.46
# 	Value computed using low-temperature polynomial:  -329.7308627080682
# 	Value computed using high-temperature polynomial: -324.0715806923912
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HCL, discontinuity in s/R detected at Tmid = 36.46
# 	Value computed using low-temperature polynomial:  15.085480047976759
# 	Value computed using high-temperature polynomial: 16.472880305634682
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species CLO, discontinuity in cp/R detected at Tmid = 51.45
# 	Value computed using low-temperature polynomial:  3.035586528080283
# 	Value computed using high-temperature polynomial: 4.116496193077657
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species CLO, discontinuity in h/RT detected at Tmid = 51.45
# 	Value computed using low-temperature polynomial:  220.05979103111767
# 	Value computed using high-temperature polynomial: 215.0509577875506
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species CLO, discontinuity in s/R detected at Tmid = 51.45
# 	Value computed using low-temperature polynomial:  21.385717764645964
# 	Value computed using high-temperature polynomial: 19.766441545331663
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species CLO2, discontinuity in cp/R detected at Tmid = 67.45
# 	Value computed using low-temperature polynomial:  3.713505171749157
# 	Value computed using high-temperature polynomial: 5.859227835476189
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species CLO2, discontinuity in h/RT detected at Tmid = 67.45
# 	Value computed using low-temperature polynomial:  172.1626593169798
# 	Value computed using high-temperature polynomial: 163.4473295525628
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species CLO2, discontinuity in s/R detected at Tmid = 67.45
# 	Value computed using low-temperature polynomial:  24.590741805307232
# 	Value computed using high-temperature polynomial: 21.513229578550973
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NOCL, discontinuity in cp/R detected at Tmid = 65.45
# 	Value computed using low-temperature polynomial:  4.283893495228644
# 	Value computed using high-temperature polynomial: 5.929520605745865
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NOCL, discontinuity in h/RT detected at Tmid = 65.45
# 	Value computed using low-temperature polynomial:  79.4932770552813
# 	Value computed using high-temperature polynomial: 72.69545585219207
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species NOCL, discontinuity in s/R detected at Tmid = 65.45
# 	Value computed using low-temperature polynomial:  24.268528705463467
# 	Value computed using high-temperature polynomial: 21.95876465999632
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HOCL, discontinuity in cp/R detected at Tmid = 52.46
# 	Value computed using low-temperature polynomial:  3.2779700134852736
# 	Value computed using high-temperature polynomial: 4.34433982808001
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HOCL, discontinuity in h/RT detected at Tmid = 52.46
# 	Value computed using low-temperature polynomial:  -189.16801985687476
# 	Value computed using high-temperature polynomial: -193.36376351569487
#
#   gas = ct.Solution("data/chem.yaml")
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\292288002.py:1: UserWarning: NasaPoly2::validate:
# For species HOCL, discontinuity in s/R detected at Tmid = 52.46
# 	Value computed using low-temperature polynomial:  21.91850877898513
# 	Value computed using high-temperature polynomial: 20.441801933526143
#
#   gas = ct.Solution("data/chem.yaml")

# %%
gas.TPX = 700, ct.one_atm, 'NH3: 1, HCLO4: 1'
gas()
# Out:
#   gas:
#
#        temperature   700 K
#           pressure   1.0132e+05 Pa
#            density   1.0227 kg/m^3
#   mean mol. weight   58.743 kg/kmol
#    phase of matter   gas
#
#                           1 kg             1 kmol
#                      ---------------   ---------------
#           enthalpy             61135        3.5912e+06  J
#    internal energy            -37944       -2.2289e+06  J
#            entropy            4570.1        2.6846e+05  J/K
#     Gibbs function        -3.138e+06       -1.8433e+08  J
#  heat capacity c_p            864.51             50784  J/K
#  heat capacity c_v            722.97             42469  J/K
#
#                       mass frac. Y      mole frac. X     chem. pot. / RT
#                      ---------------   ---------------   ---------------
#                NH3           0.14496               0.5           -33.087
#              HCLO4           0.85504               0.5           -30.256
#      [  +34 minor]                 0                 0

# %%
import cantera as ct
import numpy as np
import matplotlib.pyplot as plt

# Create a gas object for NH3 and HClO4
gas = ct.Solution('data/chem.yaml')
gas.TPX = 700, ct.one_atm, 'NH3:1, HClO4:1'

# Create a reactor using the gas
r = ct.IdealGasConstPressureReactor(gas)

# Create a reactor network
sim = ct.ReactorNet([r])

# Set the time step
time_step = 1e-6  # seconds

# Initialize arrays to store the time and temperature
time = []
temp = []

# Initialize a dictionary to store the mole fractions for each species
X = {name: [] for name in gas.species_names}

# Run the simulation for a certain number of steps
for n in range(100000):
    time.append(sim.time)
    temp.append(gas.T)
    for name in gas.species_names:
        X[name].append(gas[name].X)
    sim.advance(sim.time + time_step)

# Convert lists to numpy arrays for easier manipulation
time = np.array(time)
temp = np.array(temp)
for name in gas.species_names:
    X[name] = np.array(X[name])

plt.figure(figsize=(8, 5))

# Plot mole fractions of O2, NO, and NO2 vs. time
for name in ['O2', 'N2', 'NO', 'NO2', 'H2O', 'HCL', 'CL2']:
    plt.plot(temp, X[name], label=name)
    plt.title('(a)')
    plt.xlabel('Temprature (K)')
    plt.ylabel('Mole Fraction')
    plt.legend()
    plt.xlim(700, 2050)

plt.show()
plt.figure(figsize=(8, 5))

for name in ['NH3', 'HCLO4']:
    plt.plot(temp, X[name], label=name)
    plt.title('(b)')
    plt.xlabel('Temprature (K)')
    plt.ylabel('Mole Fraction')
    plt.legend()
    plt.xlim(700, 2050)

plt.show()
# Limit the x-axis (temperature) from 700 to 1200 K
# Out:
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species H2, discontinuity in cp/R detected at Tmid = 2.01
# 	Value computed using low-temperature polynomial:  2.3602934365979036
# 	Value computed using high-temperature polynomial: 2.9345266806587236
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species H2, discontinuity in h/RT detected at Tmid = 2.01
# 	Value computed using low-temperature polynomial:  -454.33184031861595
# 	Value computed using high-temperature polynomial: -401.57655092980355
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species H2, discontinuity in s/R detected at Tmid = 2.01
# 	Value computed using low-temperature polynomial:  2.335670747304918
# 	Value computed using high-temperature polynomial: 1.024867759488491
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species O2, discontinuity in h/RT detected at Tmid = 31.99
# 	Value computed using low-temperature polynomial:  -29.520825417914907
# 	Value computed using high-temperature polynomial: -34.33975613657743
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species O2, discontinuity in s/R detected at Tmid = 31.99
# 	Value computed using low-temperature polynomial:  16.674556680613097
# 	Value computed using high-temperature polynomial: 16.123066132160353
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species O, discontinuity in cp/R detected at Tmid = 15.99
# 	Value computed using low-temperature polynomial:  3.117504375590273
# 	Value computed using high-temperature polynomial: 2.543199132035348
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species O, discontinuity in h/RT detected at Tmid = 15.99
# 	Value computed using low-temperature polynomial:  1824.4221085638385
# 	Value computed using high-temperature polynomial: 1830.3115232901912
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species O, discontinuity in s/R detected at Tmid = 15.99
# 	Value computed using low-temperature polynomial:  10.782658929235218
# 	Value computed using high-temperature polynomial: 11.972726160618528
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species OH, discontinuity in cp/R detected at Tmid = 17
# 	Value computed using low-temperature polynomial:  3.9525086622846635
# 	Value computed using high-temperature polynomial: 2.8573846845926583
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species OH, discontinuity in h/RT detected at Tmid = 17
# 	Value computed using low-temperature polynomial:  216.6238419953234
# 	Value computed using high-temperature polynomial: 234.84558948261088
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species OH, discontinuity in s/R detected at Tmid = 17
# 	Value computed using low-temperature polynomial:  11.16614449469493
# 	Value computed using high-temperature polynomial: 13.905797492299701
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HO2, discontinuity in cp/R detected at Tmid = 33
# 	Value computed using low-temperature polynomial:  4.167257009269915
# 	Value computed using high-temperature polynomial: 4.233989707163639
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HO2, discontinuity in h/RT detected at Tmid = 33
# 	Value computed using low-temperature polynomial:  13.164479049048978
# 	Value computed using high-temperature polynomial: 6.076240452831667
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HO2, discontinuity in s/R detected at Tmid = 33
# 	Value computed using low-temperature polynomial:  18.612443379551756
# 	Value computed using high-temperature polynomial: 17.608001991824654
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species H2O2, discontinuity in cp/R detected at Tmid = 34.01
# 	Value computed using low-temperature polynomial:  4.276169411871034
# 	Value computed using high-temperature polynomial: 4.709580534471628
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species H2O2, discontinuity in h/RT detected at Tmid = 34.01
# 	Value computed using low-temperature polynomial:  -517.7585991277546
# 	Value computed using high-temperature polynomial: -526.2260420941108
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species H2O2, discontinuity in s/R detected at Tmid = 34.01
# 	Value computed using low-temperature polynomial:  18.50635947415301
# 	Value computed using high-temperature polynomial: 16.96984153713227
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species H2O, discontinuity in cp/R detected at Tmid = 18.01
# 	Value computed using low-temperature polynomial:  4.1640474673509615
# 	Value computed using high-temperature polynomial: 2.7303344722452962
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species H2O, discontinuity in h/RT detected at Tmid = 18.01
# 	Value computed using low-temperature polynomial:  -1677.869344773688
# 	Value computed using high-temperature polynomial: -1656.701813502562
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species H2O, discontinuity in s/R detected at Tmid = 18.01
# 	Value computed using low-temperature polynomial:  11.253302479772398
# 	Value computed using high-temperature polynomial: 14.675098919376222
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NO, discontinuity in cp/R detected at Tmid = 30
# 	Value computed using low-temperature polynomial:  4.089092474717589
# 	Value computed using high-temperature polynomial: 3.2960583419518548
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NO, discontinuity in h/RT detected at Tmid = 30
# 	Value computed using low-temperature polynomial:  332.32223943862215
# 	Value computed using high-temperature polynomial: 333.9928265749112
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NO, discontinuity in s/R detected at Tmid = 30
# 	Value computed using low-temperature polynomial:  16.494587750167682
# 	Value computed using high-temperature polynomial: 17.494869312687428
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HNO, discontinuity in cp/R detected at Tmid = 31.01
# 	Value computed using low-temperature polynomial:  4.376254210661443
# 	Value computed using high-temperature polynomial: 3.2581988524113092
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HNO, discontinuity in h/RT detected at Tmid = 31.01
# 	Value computed using low-temperature polynomial:  360.4632502873218
# 	Value computed using high-temperature polynomial: 364.20570970082986
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HNO, discontinuity in s/R detected at Tmid = 31.01
# 	Value computed using low-temperature polynomial:  17.151059485404996
# 	Value computed using high-temperature polynomial: 18.61195955401731
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NO2, discontinuity in cp/R detected at Tmid = 46
# 	Value computed using low-temperature polynomial:  3.904397441601288
# 	Value computed using high-temperature polynomial: 4.982938509880686
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NO2, discontinuity in h/RT detected at Tmid = 46
# 	Value computed using low-temperature polynomial:  66.88836716510603
# 	Value computed using high-temperature polynomial: 55.292490922222285
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NO2, discontinuity in s/R detected at Tmid = 46
# 	Value computed using low-temperature polynomial:  21.35631017256402
# 	Value computed using high-temperature polynomial: 18.68363726893214
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NO3, discontinuity in cp/R detected at Tmid = 62
# 	Value computed using low-temperature polynomial:  2.8599469217515505
# 	Value computed using high-temperature polynomial: 7.6394565566101384
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NO3, discontinuity in h/RT detected at Tmid = 62
# 	Value computed using low-temperature polynomial:  121.7403218713121
# 	Value computed using high-temperature polynomial: 99.64588216495636
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NO3, discontinuity in s/R detected at Tmid = 62
# 	Value computed using low-temperature polynomial:  24.24236383964681
# 	Value computed using high-temperature polynomial: 16.881393285673752
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HNO3, discontinuity in cp/R detected at Tmid = 63.01
# 	Value computed using low-temperature polynomial:  2.896001746879859
# 	Value computed using high-temperature polynomial: 8.28041384629274
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HNO3, discontinuity in h/RT detected at Tmid = 63.01
# 	Value computed using low-temperature polynomial:  -273.5114326835195
# 	Value computed using high-temperature polynomial: -297.4638475529988
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HNO3, discontinuity in s/R detected at Tmid = 63.01
# 	Value computed using low-temperature polynomial:  25.352489902160983
# 	Value computed using high-temperature polynomial: 17.34352562349725
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N2O, discontinuity in cp/R detected at Tmid = 44.01
# 	Value computed using low-temperature polynomial:  2.7290206655445624
# 	Value computed using high-temperature polynomial: 4.936953766253963
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N2O, discontinuity in h/RT detected at Tmid = 44.01
# 	Value computed using low-temperature polynomial:  201.1287853757643
# 	Value computed using high-temperature polynomial: 188.32406322281457
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N2O, discontinuity in s/R detected at Tmid = 44.01
# 	Value computed using low-temperature polynomial:  19.78453205380361
# 	Value computed using high-temperature polynomial: 16.16527499914631
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N, discontinuity in cp/R detected at Tmid = 14
# 	Value computed using low-temperature polynomial:  2.5
# 	Value computed using high-temperature polynomial: 2.4183681526238483
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N, discontinuity in h/RT detected at Tmid = 14
# 	Value computed using low-temperature polynomial:  4009.974128571428
# 	Value computed using high-temperature polynomial: 4011.972502265849
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N, discontinuity in s/R detected at Tmid = 14
# 	Value computed using low-temperature polynomial:  10.791552644038147
# 	Value computed using high-temperature polynomial: 11.027858589056674
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N2, discontinuity in cp/R detected at Tmid = 28.01
# 	Value computed using low-temperature polynomial:  3.5271995524316657
# 	Value computed using high-temperature polynomial: 2.991318670260152
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N2, discontinuity in h/RT detected at Tmid = 28.01
# 	Value computed using low-temperature polynomial:  -33.84950540910287
# 	Value computed using high-temperature polynomial: -30.014373590372557
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N2, discontinuity in s/R detected at Tmid = 28.01
# 	Value computed using low-temperature polynomial:  14.731123809007618
# 	Value computed using high-temperature polynomial: 15.750469263911164
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NH, discontinuity in cp/R detected at Tmid = 15.01
# 	Value computed using low-temperature polynomial:  3.4973032768450136
# 	Value computed using high-temperature polynomial: 2.803592191937497
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NH, discontinuity in h/RT detected at Tmid = 15.01
# 	Value computed using low-temperature polynomial:  2794.587385852091
# 	Value computed using high-temperature polynomial: 2809.890030968343
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NH, discontinuity in s/R detected at Tmid = 15.01
# 	Value computed using low-temperature polynomial:  11.314277644356071
# 	Value computed using high-temperature polynomial: 13.301088159661433
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NH2, discontinuity in cp/R detected at Tmid = 16.02
# 	Value computed using low-temperature polynomial:  4.173197169392958
# 	Value computed using high-temperature polynomial: 2.897807489198446
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NH2, discontinuity in h/RT detected at Tmid = 16.02
# 	Value computed using low-temperature polynomial:  1348.4601828997306
# 	Value computed using high-temperature polynomial: 1365.1639792684261
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NH2, discontinuity in s/R detected at Tmid = 16.02
# 	Value computed using low-temperature polynomial:  11.485614964294973
# 	Value computed using high-temperature polynomial: 14.420917202350426
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NH3, discontinuity in cp/R detected at Tmid = 17.03
# 	Value computed using low-temperature polynomial:  4.226771830953539
# 	Value computed using high-temperature polynomial: 2.8114178663478895
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NH3, discontinuity in h/RT detected at Tmid = 17.03
# 	Value computed using low-temperature polynomial:  -391.9824376631303
# 	Value computed using high-temperature polynomial: -383.87804674836195
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NH3, discontinuity in s/R detected at Tmid = 17.03
# 	Value computed using low-temperature polynomial:  11.42668357934718
# 	Value computed using high-temperature polynomial: 13.890380842497086
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N2H2, discontinuity in cp/R detected at Tmid = 30.02
# 	Value computed using low-temperature polynomial:  4.620867164672767
# 	Value computed using high-temperature polynomial: 1.578562095133084
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N2H2, discontinuity in h/RT detected at Tmid = 30.02
# 	Value computed using low-temperature polynomial:  811.6980144424637
# 	Value computed using high-temperature polynomial: 827.1087739272671
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N2H2, discontinuity in s/R detected at Tmid = 30.02
# 	Value computed using low-temperature polynomial:  16.489904578633684
# 	Value computed using high-temperature polynomial: 21.13828674308682
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N2H4, discontinuity in cp/R detected at Tmid = 32.04
# 	Value computed using low-temperature polynomial:  3.8509837417935104
# 	Value computed using high-temperature polynomial: 5.216870901448034
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N2H4, discontinuity in h/RT detected at Tmid = 32.04
# 	Value computed using low-temperature polynomial:  318.73670103322644
# 	Value computed using high-temperature polynomial: 294.7995633637798
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species N2H4, discontinuity in s/R detected at Tmid = 32.04
# 	Value computed using low-temperature polynomial:  19.045643847026646
# 	Value computed using high-temperature polynomial: 14.709854221933698
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species CL, discontinuity in cp/R detected at Tmid = 35.45
# 	Value computed using low-temperature polynomial:  2.314348174967176
# 	Value computed using high-temperature polynomial: 2.9330705191450934
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species CL, discontinuity in h/RT detected at Tmid = 35.45
# 	Value computed using low-temperature polynomial:  393.12822734351136
# 	Value computed using high-temperature polynomial: 389.3158975068384
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species CL, discontinuity in s/R detected at Tmid = 35.45
# 	Value computed using low-temperature polynomial:  14.690592882172336
# 	Value computed using high-temperature polynomial: 13.613476787496289
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species CL2, discontinuity in cp/R detected at Tmid = 70.9
# 	Value computed using low-temperature polynomial:  3.223335988068876
# 	Value computed using high-temperature polynomial: 4.713975354415703
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species CL2, discontinuity in h/RT detected at Tmid = 70.9
# 	Value computed using low-temperature polynomial:  -11.942798984430285
# 	Value computed using high-temperature polynomial: -16.581566761583947
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species CL2, discontinuity in s/R detected at Tmid = 70.9
# 	Value computed using low-temperature polynomial:  21.626535384234572
# 	Value computed using high-temperature polynomial: 19.85090300166566
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HCL, discontinuity in cp/R detected at Tmid = 36.46
# 	Value computed using low-temperature polynomial:  3.524864113130429
# 	Value computed using high-temperature polynomial: 2.8184036072188126
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HCL, discontinuity in h/RT detected at Tmid = 36.46
# 	Value computed using low-temperature polynomial:  -329.7308627080682
# 	Value computed using high-temperature polynomial: -324.0715806923912
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HCL, discontinuity in s/R detected at Tmid = 36.46
# 	Value computed using low-temperature polynomial:  15.085480047976759
# 	Value computed using high-temperature polynomial: 16.472880305634682
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species CLO, discontinuity in cp/R detected at Tmid = 51.45
# 	Value computed using low-temperature polynomial:  3.035586528080283
# 	Value computed using high-temperature polynomial: 4.116496193077657
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species CLO, discontinuity in h/RT detected at Tmid = 51.45
# 	Value computed using low-temperature polynomial:  220.05979103111767
# 	Value computed using high-temperature polynomial: 215.0509577875506
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species CLO, discontinuity in s/R detected at Tmid = 51.45
# 	Value computed using low-temperature polynomial:  21.385717764645964
# 	Value computed using high-temperature polynomial: 19.766441545331663
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species CLO2, discontinuity in cp/R detected at Tmid = 67.45
# 	Value computed using low-temperature polynomial:  3.713505171749157
# 	Value computed using high-temperature polynomial: 5.859227835476189
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species CLO2, discontinuity in h/RT detected at Tmid = 67.45
# 	Value computed using low-temperature polynomial:  172.1626593169798
# 	Value computed using high-temperature polynomial: 163.4473295525628
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species CLO2, discontinuity in s/R detected at Tmid = 67.45
# 	Value computed using low-temperature polynomial:  24.590741805307232
# 	Value computed using high-temperature polynomial: 21.513229578550973
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NOCL, discontinuity in cp/R detected at Tmid = 65.45
# 	Value computed using low-temperature polynomial:  4.283893495228644
# 	Value computed using high-temperature polynomial: 5.929520605745865
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NOCL, discontinuity in h/RT detected at Tmid = 65.45
# 	Value computed using low-temperature polynomial:  79.4932770552813
# 	Value computed using high-temperature polynomial: 72.69545585219207
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species NOCL, discontinuity in s/R detected at Tmid = 65.45
# 	Value computed using low-temperature polynomial:  24.268528705463467
# 	Value computed using high-temperature polynomial: 21.95876465999632
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HOCL, discontinuity in cp/R detected at Tmid = 52.46
# 	Value computed using low-temperature polynomial:  3.2779700134852736
# 	Value computed using high-temperature polynomial: 4.34433982808001
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HOCL, discontinuity in h/RT detected at Tmid = 52.46
# 	Value computed using low-temperature polynomial:  -189.16801985687476
# 	Value computed using high-temperature polynomial: -193.36376351569487
#
#   gas = ct.Solution('data/chem.yaml')
# C:\Users\tahze\AppData\Local\Temp\ipykernel_1104\960370265.py:6: UserWarning: NasaPoly2::validate:
# For species HOCL, discontinuity in s/R detected at Tmid = 52.46
# 	Value computed using low-temperature polynomial:  21.91850877898513
# 	Value computed using high-temperature polynomial: 20.441801933526143
#
#   gas = ct.Solution('data/chem.yaml')

# %%
plt.figure(figsize=(8, 5))

# Plot mole fractions of O2, NO, and NO2 vs. time
for name in ['O2', 'N2', 'NO', 'NO2', 'H2O', 'HCL', 'CL2']:
    plt.plot(time*1e3, X[name], label=name)
    plt.title('(a)')
    plt.xlabel('Time (ns)')
    plt.ylabel('Mole Fraction')
    plt.legend()
    plt.xlim(0.2, 0.3)

plt.show()
plt.figure(figsize=(8, 5))

for name in ['NH3', 'HCLO4']:
    plt.plot(time*1e3, X[name], label=name)
    plt.title('(b)')
    plt.xlabel('Time (ns)')
    plt.ylabel('Mole Fraction')
    plt.legend()
    plt.xlim(0, 0.8)

plt.show()
# Limit the x-axis (temperature) from 700 to 1200 K

# %%
plt.style.use('default')


plt.figure(figsize=(8, 5))
plt.plot(time*1e3, temp)
plt.xlabel('Time (ns)', fontsize=12)
plt.ylabel('Temperature (K)', fontsize=12)
plt.title('Ignition Delay for AP Monopropellant Flame')
plt.xlim(0, 0.5)
plt.grid()
plt.show()

# %%
plt.style.use('default')


plt.figure(figsize=(8, 5))
plt.plot(time*1e3, temp)
plt.xlabel('Time (ns)', fontsize=12)
plt.ylabel('Temperature (K)', fontsize=12)
plt.title('Progression of Combustion Temperature')
plt.xlim(0, 10)
plt.grid()
plt.show()

# %%
gas()
# Out:
#   gas:
#
#        temperature   2610.8 K
#           pressure   1.0132e+05 Pa
#            density   0.12441 kg/m^3
#   mean mol. weight   26.652 kg/kmol
#    phase of matter   gas
#
#                           1 kg             1 kmol
#                      ---------------   ---------------
#           enthalpy             61135        1.6293e+06  J
#    internal energy       -7.5333e+05       -2.0078e+07  J
#            entropy             10540         2.809e+05  J/K
#     Gibbs function       -2.7455e+07       -7.3173e+08  J
#  heat capacity c_p            1596.5             42548  J/K
#  heat capacity c_v            1284.5             34234  J/K
#
#                       mass frac. Y      mole frac. X     chem. pot. / RT
#                      ---------------   ---------------   ---------------
#                 H2        0.00051205         0.0067693           -25.358
#                 O2           0.30198           0.25152           -31.127
#                  O          0.007359          0.012259           -15.563
#                  H        0.00012476         0.0032988           -12.679
#                 OH          0.024845          0.038935           -28.242
#                HO2        4.9516e-05        3.9983e-05           -43.805
#               H2O2        1.9816e-06        1.5527e-06           -56.484
#                H2O            0.2308           0.34145           -40.921
#                 NO          0.012624          0.011213           -30.613
#                HNO        4.5009e-07        3.8678e-07           -43.292
#               HONO        2.3561e-07        1.3357e-07           -58.855
#                NO2        1.6949e-05         9.819e-06           -46.176
#                NO3         6.858e-11        2.9478e-11            -61.74
#               HNO3        1.0032e-10        4.2432e-11           -74.418
#                N2O        3.8187e-07        2.3124e-07           -45.663
#                  N        1.3473e-07        2.5636e-07            -15.05
#                 N2           0.11332           0.10781           -30.099
#                 NH        1.2143e-08        2.1554e-08           -27.728
#                NNH        1.5067e-09        1.3837e-09           -42.778
#                NH2         2.082e-09        3.4631e-09           -40.407
#                NH3        1.0881e-09        1.7028e-09           -53.086
#               N2H2        5.1662e-14         4.585e-14           -55.457
#               H2NO        1.8077e-10        1.5045e-10           -55.971
#                 CL          0.076516          0.057525           -20.579
#                CL2        0.00044561        0.00016751           -41.159
#                HCL           0.23062           0.16859           -33.258
#                CLO        0.00058668        0.00030391           -36.143
#               CLOH        9.7724e-05         4.965e-05           -48.821
#               CLOO        3.5413e-08        1.3993e-08           -51.706
#               CLO2        5.2848e-08        2.0883e-08           -51.706
#               NOCL        1.7177e-06         6.994e-07           -51.192
#               HOCL        9.1037e-05        4.6253e-05           -48.821
#      [   +4 minor]        1.2828e-15        4.4852e-16

# %%
for i, t in enumerate(time):
    if(X['NH3'][i] < 1e-8):
        print(r.mass*1000/(t*1.95))
        break
# Out:
# 1914042.7730302988

# %%
r.mass
# Out:
# 1.0226730536300892
